# %%
pip install ascii_magic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.2/733.2 kB 11.4 MB/s eta 0:00:00
# ...

# %%
import ascii_magic
from ascii_magic import AsciiArt
tbmm = AsciiArt.from_image("tbmm.png")
tbmm.to_terminal()
# Out:
# ShVVdhhhVVVVVdddddddddddddd444444444444444444444444444444444444dddddddddddddVVVVVVVhhhhhgggggSSSSSSggghdVVVVhgSqmmm66pFF
# hddddddddddddddddd444444444444444EEEEEEEEEEEEEEEEEEEEEEEEEE444444444444444ddddddddddVVVVhhhhgggghVdEXPPZGXXg4VgShVSqSm66
# 44dddddd44444444444444444444444EEEEEEEEEEEEEEEgggggEEEEEEEEEEEEEE444444444444444dddddddVhhhhhVdXZGZk&ApAYPgg4dd5XgEdhSm6
# dd4EEEEEEE4444444EEEEEEEEEEEEEEEEEggggggggXgXXXXXgggggggggEEEEEEEEEEEEEEEEE444444dddddVdEddXPk8@$$$KWF1&kbPPPXECddVgSqqm
# 44EEEEEggggEEggggEEEEEEEEEEEEEgggXXXXXXXXXXXXXXXXXXXXXXXggggggggggggggggEEEEEE44444Edgk$K$UHDBWBBBBWYcsYkZPPXgqjqhgSSSqq
# 4EEggggggXXGbbZGXXXXPPXggggggXXXXPXXXXXXXXXXXXXXXXXPPPPPPPXXXXXXXXXXXggggggEEEEEEEEXXG8DDHDBBWBBDDD@I<LXbPg4dVSnphgggSSS
# 4EggggggXXPGGGPPPPPGGPPPPXPPPXPPGPPPPPPPPPPPPPPPPPGGGGGGGPPPPPPPPXXXXXXXXXgggggXXPk$HDBWWDDDDDHK@@@&S4dSP4ddVVd22VhgggSS
# 4EEEEgggggXXXPPPPGGZZZZGGPPPPGZbZGGPPPPGZbZGGPGGGGGGGGGGGGGGGPPPPPPPXXXXXXXXXXXXGbk&KBWWNWWDDK$U&kbGPXq2EddddVdmwdhhgggg
# ...

# %%
sepet = []

while True:
  sepetcik = input("Lütfen sepete eklemek istediğiniz şeyi yazınız (Çıkmak için 0 giriniz): ")
  if sepetcik == "0":
    break
  sepet.append(sepetcik)

print("Sepetinizdeki öğeler:", sepet)
# Out:
# Lütfen sepete eklemek istediğiniz şeyi yazınız (Çıkmak için 0 giriniz): s
# Lütfen sepete eklemek istediğiniz şeyi yazınız (Çıkmak için 0 giriniz): atom bombası
# Lütfen sepete eklemek istediğiniz şeyi yazınız (Çıkmak için 0 giriniz): 0
# Sepetinizdeki öğeler: ['s', 'atom bombası']
