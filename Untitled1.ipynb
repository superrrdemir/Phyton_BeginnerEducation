# %%
import random
rastgele_sayi = random.randint(1,7)
print(rastgele_sayi)
if rastgele_sayi == 1:
    print("Pazartesi Menü: Patates Kızartması Yumurta Efsane Süper Ultra Mega Acılı Tost")
elif rastgele_sayi == 2:
    print("Salı Menü: Tost Harika b ir sucuk")
elif rastgele_sayi == 3:
    print("Çarşamba Menü: Patates Kızartması Hamburger Acılı")
elif rastgele_sayi == 4:
    print("Perşembe Menü: Hiçbir şey (:")
elif rastgele_sayi == 5:
    print("Cuma Menü: Mkarna Harika bir spagetti ve radyo aftik madde")
elif rastgele_sayi == 6:
    print("Cumartesi Menü: Patates Kızartması")
elif rastgele_sayi == 7:
    print("Pazar Menü: Hamburger")
# Out:
# 3
# Çarşamba Menü: Patates Kızartması Hamburger Acılı

# %%
Oyuncu_Adı = input("Lütfen Oyuncu Adınızı Giriniz:")
print(Oyuncu_Adı)
Şifre = input("Lütfen Şifrenizi Giriniz:")
print(Şifre)
if Şifre == "Haşmet Dayı" or Şifre == "Minecraft Çok eylenceli":
  print("Tebrikler Başarılı Bir Giriş Yaptınız")
else:
      print("GÖRÜŞÜRÜZZ!!!")
# Out:
# Lütfen Oyuncu Adınızı Giriniz:fsdaf
# fsdaf
# Lütfen Şifrenizi Giriniz:Haşmet Dayı
# Haşmet Dayı
# Tebrikler Başarılı Bir Giriş Yaptınız
