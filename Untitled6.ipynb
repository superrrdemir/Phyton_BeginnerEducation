# %%
carpim = 1
eklenen_sayı = int(input("Lütfen sayı giriniz"))
while(eklenen_sayı != 0)
  carpim *= int(eklenen_sayı)
  eklenen_sayı = input("Lütfe sayınızı giriniz")
  print("çıkmak için 0'a basınız")
print("girdiğiniz sayıların toplamı:",carpim,"olarak görülemektedir")
# Out:
#   File "<ipython-input-5-1fc5826263fc>", line 3
#     while(eklenen_sayı != 0)
#                             ^
# SyntaxError: expected ':'
