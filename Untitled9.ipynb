# %%
import random

print("HAŞMET DAYININ RESTORANINA HOŞ GELDİNİZZZZZZZZZZ BURASI BENİMMMM RESTORANIM")
Pazratesi_Çorbalar = ["1.ÇORBA", "2.ATOMİK SIVI", "3.CANIM İSTEMEDİ", "4.TUNG TUNG TUNG SAHUR", "..... YANMIŞ", "5.SİPER ÇORBA", "HALAY ÇEKEN TAVUK", "NOKİA", "HAHAHAHAHAHHA ÇORBASI", "10.ZÜRAFA"]
Salı_Ana_Yemekler = ["Mkarna", "Atom çorbası", "Trallalelorallala", "HAVLU", "KAN", "PİZZA", "İSTEMEDİM", "BENNNNNNNNNNNNNNNNNNNNNN U S B BELEKKKKKKKKKKK", "HAVALI TAVŞAN", "noktacık"]
Çarşamba_TATLILAR = ["TATLI", "BIRR BIRRR PATABİR", "HAAAHAHAHAHAHAHA BEN HAVALI TATLI", "IIIIIII I AM STEVEEEEE", "CANIM İSTEMEDİ", "PASTA", "PİLAVLI PİLAV", "SOĞAN", "SONİCCCCCC"]


tüm_elemanlar = Pazratesi_Çorbalar + Salı_Ana_Yemekler + Çarşamba_TATLILAR


rastgele_seçimler = random.sample(tüm_elemanlar, 1)


print("Rastgele seçilenler:")
for eleman in rastgele_seçimler:
    print(eleman)
# Out:
# HAŞMET DAYININ RESTORANINA HOŞ GELDİNİZZZZZZZZZZ BURASI BENİMMMM RESTORANIM
# Rastgele seçilenler:
# HAHAHAHAHAHHA ÇORBASI
