# %%
import os
dosya = open("HAŞMET DAYI RESTORANI ÜYELERİİİİ.txt","w")
dosya.close()

# %%
okuma = open("HAŞMET DAYI RESTORANI ÜYELERİİİİ.txt","r")
print(okuma.read())
okuma.close()
# Out:
# HAŞMET DAYI(PATRONNNNNNNNN HER ŞEYİ KONTROL EDER)
# MİKARİ (AŞÇI(EKSTRA OLARAK ONA İKİNCİ PATRON DİYEBİLİRSİNİZ))
# EBUBEKİR (GARSON)
# ÖĞRETMENİMİZ (YEMEK TADICI)
# Alİ(KASİER)
# HER ZAMAN YENİ ÜYELİRİ BEKLERİZ
# HOŞÇA KALIN İYİ ZEHİRLENMELER
