# %%
def sayı_rakamı_toplama(sayı):
    toplam = 0
    while sayı > 0:
        rakam = sayı % 10
        toplam += rakam
        sayı //= 10
    return toplam

giriş_sayısı = int(input("Bir sayı girin: "))
sonuç = sayı_rakamı_toplama(giriş_sayısı)
print("Rakamların toplamı:", sonuç)
# Out:
# Bir sayı girin: 23
# Rakamların toplamı: 5
