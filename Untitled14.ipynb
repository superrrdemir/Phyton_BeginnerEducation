# %%
def kimliğim():
    ad = input("adım:")
    takma_ad = input("takma adım:")
    soyad = input("soyadım:")
    yaş = input("yaşım:")
    okul = input("okulum:")
kimliğim()
# Out:
# adım:Demir
# takma adım:Haşmet Dayı
# soyadım:Çebi
# yaşım:11
# okulum:Şahinkaya

# %%
kimliğim()
# Out:
# adım:Demir
# takma adım:Haşmet Dayı AYRICA İKİNCİ KİMLİĞİM
# soyadım:Çebi
# yaşım:11
# okulum:Şahinkaya
# yaşım: 11
# okulum:Şahinkaya

# %%
def artı()
  print("artı")
  ilk_sayı = int(input(ilk_sayı))
  ikinci_sayı = int(input(ikinci_sayı))
  toplam = ilk_sayı + ikinci_sayı
  print("Toplam:",toplam)

def çıkartma()
  print("çıkart")
  ilk_sayı = int(input(ilk_sayı))
  ikinci_sayı = int(input(ikinci_sayı))
 çıkartma = ilk_sayı - ikinci_sayı
  print("çıkartma:",çıkart)

def çarpma()
  print("çarp")
  ilk_sayı = int(input(ilk_sayı))
  ikinci_sayı = int(input(ikinci_sayı))
  çarpma = ilk_sayı * ikinci_sayı
  print("çarpma:",çarp)

 def bölme()
  print("bölüm")
  ilk_sayı = int(input(ilk_sayı))
  ikinci_sayı = int(input(ikinci_sayı))
  bölme = ilk_sayı \ ikinci_sayı
  print("bölüm:",bölme)

# %% [markdown]
# # Not ortalması hesaplama
#
# Matematik dersinden bir sınıf 3 sınazv oluyor diyelim. Bu dersin not
# ortalaması hesaplamak istiyorsak 3 tane sınav notumu toplar 3 e böleriz.
# Benzer şekilde türkçe dersinden 4 sınav oluyoır . bu 4 sınavdan not
# ortalması hesaplamak için 4 sınavıjn notu toplar 4 e böleriz
#
#
# Sonuç Kaç tane sınav notları toplar , not sayısına
# bölerim.

# %%
#1. Yöntem Not ortalama
def not_ortalama():
 sayı = int(input("Notunuzu Giriniz(çıkmak için 0 yazınız):"))
 toplam = 0
 ortalama = 0
 while(sayi != -1):
  toplam += sayi
  girilen_not_sayisi += 1 # Her not girdiğinde 1 değer alcak
  sayi = int(input("Notunuzu Giriniz(Çıkmak için -1 yaz):"))
  if(sayi == 0): # 0 Değeri girilirse döngüyü kır
    break # Döngüyü kır
  # Artık ortalmayı alabilirim. (Whlie dışında)
  ortalama = toplam / girilen_not_sayısı
  print("Ortalamanız:", ortalama)

# %%
def not_():
    not_ = input("bir not lütfen giriniz")
    if 61 >= not_ <= 100:
        print("helel olsun geçtin")
    elif 41 >= not_ <= 60:
        print("hadi iyisin")
    elif not_ == 0:
        print("ÖLDÜN SEN")

# %%
#2. yöntem - for ile
def not_for_hesaplama(sayı_adedi):
  toplam = 0
  ortalma = 0
  for a in range(0,sayı_adedi):
    sayi = int(input("Lütfen notunuzu giriniz:"))
    toplam += sayi
  ortalama = toplam / sayı_adedi
  print("Ortalamanız:",ortalama)

# %%
# Out:
# Lütfen kaç adet not gireceksiniz:2
# Lütfen notunuzu giriniz:3
# Lütfen notunuzu giriniz:3
# Ortalamanız: 3.0
